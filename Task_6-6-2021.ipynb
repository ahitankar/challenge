# %% [markdown]
# # 1

# %%
import pandas as pd

# %%
df= pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#Selecting rows where quantity is over 2
df[df.quantity > 2]
# Out:
#       order_id  quantity                            item_name  \
# 409        178         3                         Chicken Bowl
# 445        193         3                                 Bowl
# 689        284         3                    Canned Soft Drink
# 818        338         3                        Bottled Water
# 850        350         3                    Canned Soft Drink
# 917        379         3                    Canned Soft Drink
# 1254       511         4                      Chicken Burrito
# 1255       511         3                        Steak Burrito
# 1257       511         4         Chips and Fresh Tomato Salsa
# 1425       577         4                        Bottled Water
# 1514       616         3                         Chicken Bowl
# 1559       633         3                    Canned Soft Drink
# 1880       759         4                        Bottled Water
# 2235       901         4                          Canned Soda
# ...

# %%
# group by order_id and sort based on quantity
c= df.groupby('order_id')
c=c.sum()
c=c.sort_values(['quantity'])

# %%
c
# Out:
#           quantity
# order_id
# 917              1
# 819              1
# 821              1
# 512              1
# 1273             1
# ...            ...
# 759             18
# 1660            19
# 1786            20
# 926             23
# 1443            35
#
# [1834 rows x 1 columns]

# %%
#delete duplicates in item_name
df.drop_duplicates('item_name')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 16           8         1                        Chicken Burrito
# 18           9         2                            Canned Soda
# 21          11         1                       Barbacoa Burrito
# ...

# %%
df.boxplot('quantity')

# %%
#select all records with item_name as Chicken Burrito
df[df['item_name']=='Chicken Burrito']
# Out:
#       order_id  quantity        item_name  \
# 16           8         1  Chicken Burrito
# 17           9         1  Chicken Burrito
# 23          12         1  Chicken Burrito
# 29          15         1  Chicken Burrito
# 45          21         1  Chicken Burrito
# ...        ...       ...              ...
# 4556      1811         1  Chicken Burrito
# 4558      1812         1  Chicken Burrito
# 4559      1812         1  Chicken Burrito
# 4566      1816         1  Chicken Burrito
# 4569      1817         1  Chicken Burrito
#
#                                      choice_description item_price
# 16    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# 17    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...     $8.49
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...    $10.98
# 29    [Tomatillo-Green Chili Salsa (Medium), [Pinto ...     $8.49
# 45    [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $10.98
# ...

# %%
#remove rows with null values
df.dropna()
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# ...

# %% [markdown]
# # 2

# %%
df= pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt',sep=' ')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      20 non-null     object
#  1   calories  20 non-null     int64
#  2   sodium    20 non-null     int64
#  3   alcohol   20 non-null     float64
#  4   cost      20 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 928.0+ bytes

# %%
df
# Out:
#                     name  calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11           Coors_Light       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %%
#sort based on sodium content
df.sort_values('sodium')
# Out:
#                     name  calories  sodium  alcohol  cost
# 14                 Kirin       149       6      5.0  0.79
# 18   Olympia_Goled_Light        72       6      2.9  0.46
# 19         Schlitz_Light        97       7      4.2  0.47
# 3            Kronenbourg       170       7      5.2  0.73
# 9        Budweiser_Light       113       8      3.7  0.40
# 8            Miller_Lite        99      10      4.3  0.43
# 12        Michelob_Light       135      11      4.2  0.50
# 4               Heineken       152      11      5.0  0.77
# 2              Lowenbrau       157      15      0.9  0.48
# 11           Coors_Light       102      15      4.1  0.46
# 15     Pabst_Extra_Light        68      15      2.3  0.38
# 0              Budweiser       144      15      4.7  0.43
# 10                 Coors       140      18      4.6  0.44
# 13                 Becks       150      19      4.7  0.76
# 1                Schlitz       151      19      4.9  0.43
# ...

# %%
#find name with highest calories
df[df['calories']==max(df['calories'])]
# Out:
#          name  calories  sodium  alcohol  cost
# 6  Augsberger       175      24      5.5   0.4

# %%
#Find average cost of all the products

# %%
sum1=df['cost'].sum()

# %%
average = sum1/df.count()

# %%
average['cost']
# Out:
# 0.49450000000000005

# %%
#select products whose colories is between 140-170
c=df['calories'].between(140,170)

# %%
df['name'].where(c==True)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# Name: name, dtype: object

# %% [markdown]
# # 3

# %%
df=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')

# %%
df
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
#select years with murder between 12000-20000
df[df['Murder'].between(12000,20000)]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# 12  1972   208230000   8248800   834900   7413900   18670          46850
# 13  1973   209851000   8718100   875910   7842200   19640          51400
# 16  1976   214659000  11349700  1004210  10345500   18780          57080
# 17  1977   216332000  10984500  1029580   9955000   19120          63500
# 18  1978   218059000  11209000  1085550  10123400   19560          67610
# 23  1983   233981000  12108600  1258090  10850500   19310          78920
# 24  1984   236158000  11881800  1273280  10608500   18690          84230
# ...

# %%
df[['Murder','Robbery']]
# Out:
#     Murder  Robbery
# 0     9110   107840
# 1     8740   106670
# 2     8530   110860
# 3     8640   116470
# 4     9360   130390
# 5     9960   138690
# 6    11040   157990
# 7    12240   202910
# 8    13800   262840
# 9    14760   298850
# 10   16000   349860
# 11   17780   387700
# 12   18670   376290
# 13   19640   384220
# 14   20710   442400
# 15   20510   470500
# 16   18780   427810
# 17   19120   412610
# 18   19560   426930
# 19   21460   480700
# 20   23040   565840
# 21   22520   592910
# 22   21010   553130
# 23   19310   506570
# 24   18690   485010
# 25   18980   497870
# 26   20613   542775
# 27   20096   517704
# 28   20680   542970
# 29   21500   578330
# 30   23440   639270
# 31   24700   687730
# 32   23760   672480
# 33   24530   659870
# 34   23330   618950
# 35   21610   580510
# 36   19650   535590
# 37   18208   498534
# 38   16914   446625
# 39   15522   409371
# 40   15586   408016
# 41   16037   423557
# 42   16229   420806
# 43   16528   414235
# ...

# %%
#mean muder of each year

df.groupby('Year')['Murder'].mean()
# Out:
# Year
# 1960     9110
# 1961     8740
# 1962     8530
# 1963     8640
# 1964     9360
# 1965     9960
# 1966    11040
# 1967    12240
# 1968    13800
# 1969    14760
# 1970    16000
# 1971    17780
# 1972    18670
# 1973    19640
# 1974    20710
# 1975    20510
# 1976    18780
# 1977    19120
# 1978    19560
# 1979    21460
# 1980    23040
# 1981    22520
# 1982    21010
# 1983    19310
# 1984    18690
# 1985    18980
# 1986    20613
# 1987    20096
# 1988    20680
# 1989    21500
# 1990    23440
# 1991    24700
# 1992    23760
# 1993    24530
# 1994    23330
# 1995    21610
# 1996    19650
# 1997    18208
# 1998    16914
# 1999    15522
# 2000    15586
# 2001    16037
# 2002    16229
# 2003    16528
# 2004    16148
# 2005    16740
# 2006    17030
# 2007    16929
# 2008    16442
# 2009    15399
# 2010    14772
# 2011    14661
# 2012    14866
# 2013    14319
# 2014    14249
# Name: Murder, dtype: int64

# %%
#find max vehicle theft in a particular year
max(df['Vehicle_Theft'])
# Out:
# 1661700

# %% [markdown]
# # 4

# %%
df=pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1714 entries, 0 to 1713
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Package      1714 non-null   object
#  1   Item         1714 non-null   object
#  2   Title        1714 non-null   object
#  3   Rows         1714 non-null   int64
#  4   Cols         1714 non-null   int64
#  5   n_binary     1714 non-null   int64
#  6   n_character  1714 non-null   int64
#  7   n_factor     1714 non-null   int64
#  8   n_logical    1714 non-null   int64
#  9   n_numeric    1714 non-null   int64
#  10  CSV          1714 non-null   object
#  11  Doc          1714 non-null   object
# dtypes: int64(7), object(5)
# memory usage: 160.8+ KB

# %%
df
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
# replace all null values with 0
df.fillna(0)
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
df.dropna()
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
df.convert_dtypes()
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1714 entries, 0 to 1713
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Package      1714 non-null   object
#  1   Item         1714 non-null   object
#  2   Title        1714 non-null   object
#  3   Rows         1714 non-null   int64
#  4   Cols         1714 non-null   int64
#  5   n_binary     1714 non-null   int64
#  6   n_character  1714 non-null   int64
#  7   n_factor     1714 non-null   int64
#  8   n_logical    1714 non-null   int64
#  9   n_numeric    1714 non-null   int64
#  10  CSV          1714 non-null   object
#  11  Doc          1714 non-null   object
# dtypes: int64(7), object(5)
# memory usage: 160.8+ KB

# %%
df.iloc[1:11]
# Out:
#    Package             Item  \
# 1      AER     ArgentinaCPI
# 2      AER        BankWages
# 3      AER    BenderlyZwick
# 4      AER        BondYield
# 5      AER  CartelStability
# 6      AER        CASchools
# 7      AER      ChinaIncome
# 8      AER      CigarettesB
# 9      AER     CigarettesSW
# 10     AER  CollegeDistance
#
#                                                 Title  Rows  Cols  n_binary  \
# 1                   Consumer Price Index in Argentina    80     2         0
# 2                                          Bank Wages   474     4         2
# 3   Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                     Bond Yield Data    60     2         0
# 5                                     CartelStability   328     5         2
# 6                          California Test Score Data   420    14         1
# 7                   Chinese Real National Income Data    37     5         0
# ...

# %%
df.loc[3]
# Out:
# Package                                                      AER
# Item                                               BenderlyZwick
# Title          Benderly and Zwick Data: Inflation, Growth and...
# Rows                                                          31
# Cols                                                           5
# n_binary                                                       0
# n_character                                                    0
# n_factor                                                       0
# n_logical                                                      0
# n_numeric                                                      5
# CSV            https://vincentarelbundock.github.io/Rdatasets...
# Doc            https://vincentarelbundock.github.io/Rdatasets...
# Name: 3, dtype: object
